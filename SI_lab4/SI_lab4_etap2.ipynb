# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('Audiobooks_data_train.npz')
train_inputs = npz['inputs'].astype(np.float32)
train_targets = npz['targets'].astype(np.int32)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs = npz['inputs'].astype(np.float32)
validation_targets = npz['targets'].astype(np.int32)
npz = np.load('Audiobooks_data_test.npz')
test_inputs = npz['inputs'].astype(np.float32)
test_targets = npz['targets'].astype(np.int32)
#validation_inputs, validation_targets

# %%
input_size = 10
output_size = 2
hidden_layer_size = 200

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
batch_size = 20
max_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=8)
model.fit(train_inputs,
          train_targets,
          batch_size=batch_size,
          epochs=max_epochs,
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets),
          verbose=1)
# Out:
# Epoch 1/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7564 - loss: 0.4561 - val_accuracy: 0.7740 - val_loss: 0.3977
# Epoch 2/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7793 - loss: 0.4024 - val_accuracy: 0.7718 - val_loss: 0.3795
# Epoch 3/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7949 - loss: 0.3881 - val_accuracy: 0.7897 - val_loss: 0.3653
# Epoch 4/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7994 - loss: 0.3787 - val_accuracy: 0.7919 - val_loss: 0.3604
# Epoch 5/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.3715 - val_accuracy: 0.7964 - val_loss: 0.3734
# Epoch 6/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8033 - loss: 0.3716 - val_accuracy: 0.7830 - val_loss: 0.3697
# Epoch 7/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8047 - loss: 0.3635 - val_accuracy: 0.8009 - val_loss: 0.3663
# Epoch 8/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8058 - loss: 0.3654 - val_accuracy: 0.8009 - val_loss: 0.3552
# Epoch 9/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8064 - loss: 0.3566 - val_accuracy: 0.7830 - val_loss: 0.3663
# Epoch 10/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8080 - loss: 0.3584 - val_accuracy: 0.7919 - val_loss: 0.3556
# Epoch 11/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8145 - loss: 0.3499 - val_accuracy: 0.8009 - val_loss: 0.3554
# Epoch 12/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8083 - loss: 0.3576 - val_accuracy: 0.8076 - val_loss: 0.3512
# Epoch 13/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8075 - loss: 0.3546 - val_accuracy: 0.8098 - val_loss: 0.3599
# Epoch 14/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8094 - loss: 0.3533 - val_accuracy: 0.8076 - val_loss: 0.3514
# Epoch 15/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8134 - loss: 0.3479 - val_accuracy: 0.7875 - val_loss: 0.3635
# Epoch 16/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8134 - loss: 0.3469 - val_accuracy: 0.7852 - val_loss: 0.3638
# Epoch 17/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8125 - loss: 0.3470 - val_accuracy: 0.7875 - val_loss: 0.3623
# Epoch 18/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8134 - loss: 0.3504 - val_accuracy: 0.8031 - val_loss: 0.3426
# Epoch 19/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8111 - loss: 0.3433 - val_accuracy: 0.8121 - val_loss: 0.3397
# Epoch 20/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8150 - loss: 0.3416 - val_accuracy: 0.8054 - val_loss: 0.3498
# Epoch 21/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8148 - loss: 0.3439 - val_accuracy: 0.8054 - val_loss: 0.3512
# Epoch 22/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8150 - loss: 0.3500 - val_accuracy: 0.8009 - val_loss: 0.3434
# Epoch 23/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8136 - loss: 0.3470 - val_accuracy: 0.8076 - val_loss: 0.3384
# Epoch 24/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8181 - loss: 0.3437 - val_accuracy: 0.8031 - val_loss: 0.3525
# Epoch 25/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8184 - loss: 0.3392 - val_accuracy: 0.8076 - val_loss: 0.3347
# Epoch 26/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8209 - loss: 0.3359 - val_accuracy: 0.7987 - val_loss: 0.3470
# Epoch 27/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8139 - loss: 0.3477 - val_accuracy: 0.8054 - val_loss: 0.3393
# Epoch 28/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8181 - loss: 0.3397 - val_accuracy: 0.8009 - val_loss: 0.3571
# Epoch 29/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8203 - loss: 0.3391 - val_accuracy: 0.8054 - val_loss: 0.3580
# Epoch 30/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8175 - loss: 0.3389 - val_accuracy: 0.8076 - val_loss: 0.3466
# Epoch 31/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8220 - loss: 0.3390 - val_accuracy: 0.7785 - val_loss: 0.3586
# Epoch 32/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8192 - loss: 0.3374 - val_accuracy: 0.7964 - val_loss: 0.3498
# Epoch 33/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8209 - loss: 0.3374 - val_accuracy: 0.7964 - val_loss: 0.3537

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print('\Test loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8036 - loss: 0.3720
# \Test loss: 0.37. Test accuracy: 80.36%
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_14012/131193510.py:2: SyntaxWarning: invalid escape sequence '\T'
#   print('\Test loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
